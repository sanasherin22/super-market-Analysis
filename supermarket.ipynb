# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'/content/supermarket.csv')

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %% [markdown]
# unique values of segment

# %%
df['Sales'].nlargest(5)
# Out:
# 2697    22638.480
# 6826    17499.950
# 8153    13999.960
# 2623    11199.968
# 4190    10499.970
# Name: Sales, dtype: float64

# %% [markdown]
# top 5 sales in data set

# %%
df['Sales'].nsmallest(10)
# Out:
# 4101    0.444
# 9292    0.556
# 8658    0.836
# 4711    0.852
# 2106    0.876
# 7548    0.898
# 8033    0.984
# 2761    0.990
# 8024    1.044
# 976     1.080
# Name: Sales, dtype: float64

# %% [markdown]
# lower 5 sales in data set

# %%
df.groupby('City')['Sales'].sum()
# Out:
# City
# Aberdeen         25.500
# Abilene           1.392
# Akron          2724.244
# Albuquerque    2220.160
# Alexandria     5519.570
#                  ...
# Woonsocket      195.550
# Yonkers        7657.666
# York            817.978
# Yucaipa          50.800
# Yuma            840.865
# Name: Sales, Length: 529, dtype: float64

# %% [markdown]
# summerise average

# %%
df.groupby(['Region','Country'])['Sales'].sum()
# Out:
# Region   Country
# Central  United States    492646.9132
# East     United States    669518.7260
# South    United States    389151.4590
# West     United States    710219.6845
# Name: Sales, dtype: float64

# %%
df.pivot_table(index=['Product Name'],values='Sales',aggfunc=['sum'])
# Out:
#                                                          sum
#                                                        Sales
# Product Name
# "While you Were Out" Message Book, One Form per...    25.228
# #10 Gummed Flap White Envelopes, 100/Box              41.300
# #10 Self-Seal White Envelopes                        108.682
# #10 White Business Envelopes,4 1/8 x 9 1/2           379.214
# #10- 4 1/8" x 9 1/2" Recycled Envelopes              286.672
# ...                                                      ...
# iKross Bluetooth Portable Keyboard + Cell Phone...   477.660
# iOttie HLCRIO102 Car Mount                           215.892
# iOttie XL Car Mount                                  223.888
# invisibleSHIELD by ZAGG Smudge-Free Screen Prot...   442.554
# netTALK DUO VoIP Telephone Service                  1112.788
#
# [1849 rows x 1 columns]

# %% [markdown]
# findings of sale prodct name

# %%
df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %% [markdown]
# top 5 full details in data

# %%
df.tail(5)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country     City  \
# 9795    SH-19975     Sally Hughsby  Corporate  United States  Chicago
# 9796    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9797    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9798    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9799    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
#
#          State  Postal Code   Region       Product ID         Category  \
# ...

# %% [markdown]
# last 5 full detail in data

# %%
df['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1492
# Paper          1338
# Furnishings     931
# Phones          876
# Storage         832
# Art             785
# Accessories     756
# Chairs          607
# Appliances      459
# Labels          357
# Tables          314
# Envelopes       248
# Bookcases       226
# Fasteners       214
# Supplies        184
# Machines        115
# Copiers          66
# Name: count, dtype: int64

# %% [markdown]
# count the values of sub_category in data

# %%
df.loc[1:10,['Ship Date','Ship Mode','Customer Name']]
# Out:
#      Ship Date       Ship Mode    Customer Name
# 1   11/11/2017    Second Class      Claire Gute
# 2   16/06/2017    Second Class  Darrin Van Huff
# 3   18/10/2016  Standard Class   Sean O'Donnell
# 4   18/10/2016  Standard Class   Sean O'Donnell
# 5   14/06/2015  Standard Class  Brosina Hoffman
# 6   14/06/2015  Standard Class  Brosina Hoffman
# 7   14/06/2015  Standard Class  Brosina Hoffman
# 8   14/06/2015  Standard Class  Brosina Hoffman
# 9   14/06/2015  Standard Class  Brosina Hoffman
# 10  14/06/2015  Standard Class  Brosina Hoffman

# %%
df.iloc[1000]
# Out:
# Row ID                                                     1001
# Order ID                                         CA-2017-155488
# Order Date                                           13/11/2017
# Ship Date                                            17/11/2017
# Ship Mode                                        Standard Class
# Customer ID                                            FM-14290
# Customer Name                                      Frank Merwin
# Segment                                             Home Office
# Country                                           United States
# City                                                  Vancouver
# State                                                Washington
# Postal Code                                             98661.0
# Region                                                     West
# Product ID                                      OFF-AR-10002956
# Category                                        Office Supplies
# ...

# %% [markdown]
# details of 1000 index number in data

# %%
df.isna().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %% [markdown]
# null values in data

# %%
x=df['Postal Code'].mean()

# %%
x
# Out:
# 55273.322402696904

# %%
df['Postal Code'].fillna(x)
# Out:
# 0       42420.0
# 1       42420.0
# 2       90036.0
# 3       33311.0
# 4       33311.0
#          ...
# 9795    60610.0
# 9796    43615.0
# 9797    43615.0
# 9798    43615.0
# 9799    43615.0
# Name: Postal Code, Length: 9800, dtype: float64

# %% [markdown]
# fill the null values avrage values in postel code in data

# %%
df.replace({'Region':{'West':'W','South':'S','East':'E','North':'N'}})
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# replace the region colomn

# %%
x=df['Category']
y=df['Sales']
plt.bar(x,y)
plt.title('Relationship b/w Category&Sales')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# present the relation b/w category &sales

# %%
sns.barplot(data=df,x='Region',y='Sales',color='r')
plt.xticks(rotation=90)
plt.title('Region & Sales')
plt.show()

# %% [markdown]
# in this  region &sales data show the relation for the region sales

# %%
df[(df['Category']=='Furniture')]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 5          6  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 10        11  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9786    9787  US-2015-114377  05/11/2015  05/11/2015        Same Day
# 9787    9788  CA-2018-144491  27/03/2018  01/04/2018  Standard Class
# 9788    9789  CA-2018-144491  27/03/2018  01/04/2018  Standard Class
# 9790    9791  CA-2018-144491  27/03/2018  01/04/2018  Standard Class
# 9792    9793  CA-2015-127166  21/05/2015  23/05/2015    Second Class
#
#      Customer ID     Customer Name   Segment        Country             City  \
# ...

# %% [markdown]
# filter the category of furniture in data

# %%
ab=df.groupby('Sub-Category')['Sales'].sum().head(5)

# %%
ab
# Out:
# Sub-Category
# Accessories    164186.7000
# Appliances     104618.4030
# Art             26705.4100
# Binders        200028.7850
# Bookcases      113813.1987
# Name: Sales, dtype: float64

# %%
ab.index
# Out:
# Index(['Accessories', 'Appliances', 'Art', 'Binders', 'Bookcases'], dtype='object', name='Sub-Category')

# %%
ab.values
# Out:
# array([164186.7   , 104618.403 ,  26705.41  , 200028.785 , 113813.1987])

# %%
x=ab.index
y=ab.values
z=[0.3,0,0,0,0]
plt.pie(y,labels=x,explode=z,shadow=True,autopct='%1.1f%%')
plt.legend(bbox_to_anchor=(1,1),title='Example')
plt.show()

# %% [markdown]
# in this pie chart show that average point of top 5 sub category sales in data
